# %% [markdown]
# <a href="https://colab.research.google.com/github/yeryeong0519/netflix-disneyplus/blob/main/%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%B2%98%EB%A6%AC_%EA%B8%B0%EB%A7%90_%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 나눔 폰트 설치
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq

# 나눔 폰트 경로 설정
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
font_prop = fm.FontProperties(fname=font_path, size=12)

# 런타임 다시 시작 후 실행해야 함
# 또는 Colab의 런타임 재시작 후 아래 코드부터 실행

# 한글 폰트 설정
plt.rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# 예제
plt.figure(figsize=(8, 6))
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.title('한글 폰트 사용 예제', fontproperties=font_prop)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
# !wget http://bit.ly/3ZLyF82 -O CSS.css -q

from IPython.core.display import HTML
with open('./CSS.css', 'r') as file:
    custom_css = file.read()

HTML(custom_css)
# Out:
# <style>
#
# :root{
#     --header1_color: #204709;
#     --header2_color: #42841F;
#     --header3_color: #6EAF4B;
#     --keyword_color: #cc241d; /* import */
#     --string_color: #79740e;
#     --number_color: #b16286;
#     --def_color: #689d6a; /* class name */
#     --property_color: #458588; /* python properties */
#     --builtin_color: #689d6a;
#     --comment_color: #9f9f9f;
#     --comment_color_2: #458588; /* equals sign */
#     --operator_color: #a221f2;
#     --font_color: #3c3836; /* general font */
#     --variable2_color: #b16286; /*self keyworda */
#     --box_color: #fffdee66;
# }
#
#
# /* h1, .h1 { */
# /*     font-family: "Trebuchet MS", sans-serif; */
# /*     font-size: 2em !important; */
# /*     letter-spacing: 1px; */
# /*     /1* border-bottom: 3px solid #497564; *1/ */
# /*     /1* text-transform: uppercase; *1/ */
# /*     color: var(--header1_color); */
# /*     border-bottom: 3px solid var(--header1_color); */
# /* } */
#
# /* h1.title{ */
# ...

# %%
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
import pandas as pd
import numpy as np
import plotly.express as px
# %matplotlib inline

# %%
netflix=pd.read_csv("/content/netflix_titles.csv")
print('the size of netflix data is {}'.format(netflix.shape))
netflix.head()
# Out:
# the size of netflix data is (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
disney=pd.read_csv("/content/disney_plus_titles.csv")
print('the size of netflix data is {}'.format(disney.shape))
disney.head()
# Out:
# the size of netflix data is (1450, 12)
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# ...

# %%
netflix['platform'] = 'netflix'
disney['platform']  = 'disney'

# %%
df_all = pd.concat([netflix, disney])

# %%
# data cleaning
df_all['duration'] = np.where(df_all['rating']=='74 min','74 min', df_all['duration'] )
df_all['duration'] = np.where(df_all['rating']=='84 min','84 min', df_all['duration'] )
df_all['duration'] = np.where(df_all['rating']=='66 min','66 min', df_all['duration'] )

df_all['rating'] = np.where(df_all['rating']=='74 min', 'Nan', df_all['rating'])
df_all['rating'] = np.where(df_all['rating']=='84 min', 'Nan', df_all['rating'])
df_all['rating'] = np.where(df_all['rating']=='66 min', 'Nan', df_all['rating'])

# %% [markdown]
# ##데이터 시각화
#
# to make choropleth map so that view the origin of the contents at a glance!
#
# for more details, please refer to bar chart!
#
# the States is in dominant position while India, UK, France, Korea, Japan ranked high on the list :)

# %%
country_codes = {'afghanistan': 'AFG',
 'albania': 'ALB',
 'algeria': 'DZA',
 'american samoa': 'ASM',
 'andorra': 'AND',
 'angola': 'AGO',
 'anguilla': 'AIA',
 'antigua and barbuda': 'ATG',
 'argentina': 'ARG',
 'armenia': 'ARM',
 'aruba': 'ABW',
 'australia': 'AUS',
 'austria': 'AUT',
 'azerbaijan': 'AZE',
 'bahamas': 'BHM',
 'bahrain': 'BHR',
 'bangladesh': 'BGD',
 'barbados': 'BRB',
 'belarus': 'BLR',
 'belgium': 'BEL',
 'belize': 'BLZ',
 'benin': 'BEN',
 'bermuda': 'BMU',
 'bhutan': 'BTN',
 'bolivia': 'BOL',
 'bosnia and herzegovina': 'BIH',
 'botswana': 'BWA',
 'brazil': 'BRA',
 'british virgin islands': 'VGB',
 'brunei': 'BRN',
 'bulgaria': 'BGR',
 'burkina faso': 'BFA',
 'burma': 'MMR',
 'burundi': 'BDI',
 'cabo verde': 'CPV',
 'cambodia': 'KHM',
 'cameroon': 'CMR',
 'canada': 'CAN',
 'cayman islands': 'CYM',
 'central african republic': 'CAF',
 'chad': 'TCD',
 'chile': 'CHL',
 'china': 'CHN',
 'colombia': 'COL',
 'comoros': 'COM',
 'congo democratic': 'COD',
 'Congo republic': 'COG',
 'cook islands': 'COK',
 'costa rica': 'CRI',
 "cote d'ivoire": 'CIV',
 'croatia': 'HRV',
 'cuba': 'CUB',
 'curacao': 'CUW',
 'cyprus': 'CYP',
 'czech republic': 'CZE',
 'denmark': 'DNK',
 'djibouti': 'DJI',
 'dominica': 'DMA',
 'dominican republic': 'DOM',
 'ecuador': 'ECU',
 'egypt': 'EGY',
 'el salvador': 'SLV',
 'equatorial guinea': 'GNQ',
 'eritrea': 'ERI',
 'estonia': 'EST',
 'ethiopia': 'ETH',
 'falkland islands': 'FLK',
 'faroe islands': 'FRO',
 'fiji': 'FJI',
 'finland': 'FIN',
 'france': 'FRA',
 'french polynesia': 'PYF',
 'gabon': 'GAB',
 'gambia, the': 'GMB',
 'georgia': 'GEO',
 'germany': 'DEU',
 'ghana': 'GHA',
 'gibraltar': 'GIB',
 'greece': 'GRC',
 'greenland': 'GRL',
 'grenada': 'GRD',
 'guam': 'GUM',
 'guatemala': 'GTM',
 'guernsey': 'GGY',
 'guinea-bissau': 'GNB',
 'guinea': 'GIN',
 'guyana': 'GUY',
 'haiti': 'HTI',
 'honduras': 'HND',
 'hong kong': 'HKG',
 'hungary': 'HUN',
 'iceland': 'ISL',
 'india': 'IND',
 'indonesia': 'IDN',
 'iran': 'IRN',
 'iraq': 'IRQ',
 'ireland': 'IRL',
 'isle of man': 'IMN',
 'israel': 'ISR',
 'italy': 'ITA',
 'jamaica': 'JAM',
 'japan': 'JPN',
 'jersey': 'JEY',
 'jordan': 'JOR',
 'kazakhstan': 'KAZ',
 'kenya': 'KEN',
 'kiribati': 'KIR',
 'north korea': 'PRK',
 'south korea': 'KOR',
 'kosovo': 'KSV',
 'kuwait': 'KWT',
 'kyrgyzstan': 'KGZ',
 'laos': 'LAO',
 'latvia': 'LVA',
 'lebanon': 'LBN',
 'lesotho': 'LSO',
 'liberia': 'LBR',
 'libya': 'LBY',
 'liechtenstein': 'LIE',
 'lithuania': 'LTU',
 'luxembourg': 'LUX',
 'macau': 'MAC',
 'macedonia': 'MKD',
 'madagascar': 'MDG',
 'malawi': 'MWI',
 'malaysia': 'MYS',
 'maldives': 'MDV',
 'mali': 'MLI',
 'malta': 'MLT',
 'marshall islands': 'MHL',
 'mauritania': 'MRT',
 'mauritius': 'MUS',
 'mexico': 'MEX',
 'micronesia': 'FSM',
 'moldova': 'MDA',
 'monaco': 'MCO',
 'mongolia': 'MNG',
 'montenegro': 'MNE',
 'morocco': 'MAR',
 'mozambique': 'MOZ',
 'namibia': 'NAM',
 'nepal': 'NPL',
 'netherlands': 'NLD',
 'new caledonia': 'NCL',
 'new zealand': 'NZL',
 'nicaragua': 'NIC',
 'nigeria': 'NGA',
 'niger': 'NER',
 'niue': 'NIU',
 'northern mariana islands': 'MNP',
 'norway': 'NOR',
 'oman': 'OMN',
 'pakistan': 'PAK',
 'palau': 'PLW',
 'panama': 'PAN',
 'papua new guinea': 'PNG',
 'paraguay': 'PRY',
 'peru': 'PER',
 'philippines': 'PHL',
 'poland': 'POL',
 'portugal': 'PRT',
 'puerto rico': 'PRI',
 'qatar': 'QAT',
 'romania': 'ROU',
 'russia': 'RUS',
 'rwanda': 'RWA',
 'saint kitts and nevis': 'KNA',
 'saint lucia': 'LCA',
 'saint martin': 'MAF',
 'saint pierre and miquelon': 'SPM',
 'saint vincent and the grenadines': 'VCT',
 'samoa': 'WSM',
 'san marino': 'SMR',
 'sao tome and principe': 'STP',
 'saudi arabia': 'SAU',
 'senegal': 'SEN',
 'serbia': 'SRB',
 'seychelles': 'SYC',
 'sierra leone': 'SLE',
 'singapore': 'SGP',
 'sint maarten': 'SXM',
 'slovakia': 'SVK',
 'slovenia': 'SVN',
 'solomon islands': 'SLB',
 'somalia': 'SOM',
 'south africa': 'ZAF',
 'south sudan': 'SSD',
 'spain': 'ESP',
 'sri lanka': 'LKA',
 'sudan': 'SDN',
 'suriname': 'SUR',
 'swaziland': 'SWZ',
 'sweden': 'SWE',
 'switzerland': 'CHE',
 'syria': 'SYR',
 'taiwan': 'TWN',
 'tajikistan': 'TJK',
 'tanzania': 'TZA',
 'thailand': 'THA',
 'timor-leste': 'TLS',
 'togo': 'TGO',
 'tonga': 'TON',
 'trinidad and tobago': 'TTO',
 'tunisia': 'TUN',
 'turkey': 'TUR',
 'turkmenistan': 'TKM',
 'tuvalu': 'TUV',
 'uganda': 'UGA',
 'ukraine': 'UKR',
 'united arab emirates': 'ARE',
 'united kingdom': 'GBR',
 'united states': 'USA',
 'uruguay': 'URY',
 'uzbekistan': 'UZB',
 'vanuatu': 'VUT',
 'venezuela': 'VEN',
 'vietnam': 'VNM',
 'virgin islands': 'VGB',
 'west bank': 'WBG',
 'yemen': 'YEM',
 'zambia': 'ZMB',
 'zimbabwe': 'ZWE'}

## countries
from collections import Counter
colorscale = ["#f7fbff", "#ebf3fb", "#deebf7", "#d2e3f3", "#c6dbef", "#b3d2e9", "#9ecae1",
    "#85bcdb", "#6baed6", "#57a0ce", "#4292c6", "#3082be", "#2171b5", "#1361a9",
    "#08519c", "#0b4083", "#08306b"
]

def geoplot(ddf):
    country_with_code, country = {}, {}
    shows_countries = ", ".join(ddf['country'].dropna()).split(", ")
    for c,v in dict(Counter(shows_countries)).items():
        code = ""
        if c.lower() in country_codes:
            code = country_codes[c.lower()]
        country_with_code[code] = v
        country[c] = v

    data = [dict(
            type = 'choropleth',
            locations = list(country_with_code.keys()),
            z = list(country_with_code.values()),
            colorscale = 'tab20',
            autocolorscale = False,
            reversescale = True,
            marker = dict(
                line = dict (
                    color = 'gray',
                    width = 0.5
                ) ),
            colorbar = dict(
                autotick = False,
                title = ''),
          ) ]

    layout = dict(
        title = '',
        geo = dict(
            showframe = False,
            showcoastlines = False,
            projection = dict(
                type = 'Mercator'
            )
        )
    )

    fig = dict( data=data, layout=layout )
    iplot( fig, validate=False, filename='d3-world-map' )
    return country

country_vals = geoplot(df_all)
tabs = Counter(country_vals).most_common(25)

labels = [_[0] for _ in tabs][::-1]
values = [_[1] for _ in tabs][::-1]
trace1 = go.Bar(y=labels, x=values, orientation="h", name="", marker=dict(color="#008B8B"))

data = [trace1]
layout = go.Layout(title="국가별 컨텐츠 수", height=600, legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 사용비율 비교 platform 열을 기반으로 한 파이차트 생성 update_traces 함수를 사용하여 hovertemplate, textposition, textinfo 및 rotation 등의 트레이스 설정을 업데이트

# %%
fig2 = px.pie(df_all, names='platform',
              height=400, width=600,
              hole=0.7,
              title='사용률 비교 파이차트',
              color_discrete_sequence=['#8a2be2', '#ff69b4'])

# Update trace settings
fig2.update_traces(hovertemplate=None, textposition='outside', textinfo='percent+label', rotation=0)

# Update layout settings
fig2.update_layout(margin=dict(t=100, b=30, l=0, r=0), showlegend=False,
                   plot_bgcolor='#fafafa', paper_bgcolor='#fafafa',
                   title_font=dict(size=20, color='#555', family="Lato, sans-serif"),
                   font=dict(size=17, color='#8a8d93'),
                   hoverlabel=dict(bgcolor="#444", font_size=13, font_family="Lato, sans-serif"))

fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 데이터프레임 df_all을 'platform'과 'release_year' 열을 기준으로 그룹화, 데이터프레임 df_group_yr을 생성

# %%
df_group_yr = df_all.groupby(['platform','release_year']).count()['show_id'].reset_index()

# %% [markdown]
# 'release_year' 및 'platform'에 따른 컨텐츠 수를 나타내는 막대 차트를 생성

# %%
fig = px.bar(df_group_yr, x='release_year', y='show_id', color='platform', template='simple_white',
             color_discrete_map={'netflix': '#E50914', 'disney': '#0047AB'})

fig.update_layout(
    title={'text': '출시 연도별 컨텐츠',
           'y': 0.95,
           'x': 0.5,
           'xanchor': 'center',
           'yanchor': 'top'},
    xaxis_title='년도',
    yaxis_title='컨텐츠 수',
    legend_title='플랫폼 종류'
)

fig.update_layout(margin=dict(t=100, b=30, l=0, r=0), showlegend=True,
                  plot_bgcolor='#fafafa', paper_bgcolor='#fafafa',
                  title_font=dict(size=20, color='#555', family='Lato, sans-serif'),
                  font=dict(size=12, color='#8a8d93'),
                  hoverlabel=dict(bgcolor='#444', font_size=8, font_family='Lato, sans-serif'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 💡 Notes:
# Netflix has much more contents comparing with Disney+.
#
# You can hover over the graph and zoom in the 1930~1970. Then you will find that Disney has many old movies.
#
# According to the graph above, the number of contents from netflix has been decreased sicne 2017.

# %% [markdown]
# df_all을 복제하고, 'listed_in' 열을 쉼표로 분할하여 새로운 열을 추가

# %%
genre_count = df_all.copy()
genre_count = pd.concat([genre_count, df_all['listed_in'].str.split(',', expand=True)])

# %% [markdown]
# 데이터프레임 genre_count를 'type', 'title' 열을 기준으로 'value_vars'에 지정된 열 범위를 'melt'하여 새로운 열 'genre'을 생성

# %%
genre_count = genre_count.melt(id_vars = ['type', 'title'], value_vars = range(3), value_name = 'genre')

# %% [markdown]
# 데이터프레임 genre_count에서 'genre' 열이 결측값이 아닌 행만 선택

# %%
genre_count = genre_count[genre_count['genre'].notna()]

# %% [markdown]
# genre_count' 데이터프레임을 기반으로 한 영화 장르 히스토그램을 생성

# %%
fig = px.histogram(data_frame=genre_count, x='genre', title="영화 장르 막대 그래프")
fig.update_layout(
    plot_bgcolor='#fafafa', paper_bgcolor='#fafafa',
    title_font=dict(size=20, color='#555', family='Lato, sans-serif'),
    font=dict(size=12, color='#8a8d93'),
    hoverlabel=dict(bgcolor='#444', font_size=8, font_family='Lato, sans-serif')
)
fig.update_xaxes(tickangle=-45, tickfont=dict(size=10))
fig.update_traces(marker_color='hotpink')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 광범위한 장르로 한번에 파악하기 어렵다.
#
# 데이터프레임 df_all을 'platform' 및 'listed_in' 열을 기준으로 그룹화하고, 각 그룹에 속하는 레코드 수를 세는 작업

# %%
df_group_genre = df_all.groupby(['platform','listed_in']).count()['show_id'].reset_index()

# %% [markdown]
# 'platform'이 'netflix'인 경우에 해당하는 데이터프레임에서 'show_id' 기준으로 내림차순으로 정렬하고, 상위 10개 행을 선택

# %%
df_group_genre[df_group_genre['platform']=='netflix'].sort_values('show_id', ascending=False)[:10].style.background_gradient()
# Out:
# <style type="text/css">
# #T_28720_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_28720_row1_col2 {
#   background-color: #023c5f;
#   color: #f1f1f1;
# }
# #T_28720_row2_col2 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_28720_row3_col2 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_28720_row4_col2 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_28720_row5_col2 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_28720_row6_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_28720_row7_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_28720_row8_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_28720_row9_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_28720" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# 'platform'이 'netflix'인 경우에 해당하는 데이터프레임에서 'show_id' 기준으로 내림차순으로 정렬하고, 상위 10개 행 중 'listed_in' 열의 값을 추출하여 리스트로 변환

# %%
top10_netflix = df_group_genre[df_group_genre['platform']=='netflix'].sort_values('show_id', ascending=False)[:10]['listed_in'].values.tolist()

# %% [markdown]
# netflix' 플랫폼에서 가장 많은 컨텐츠를 가진 상위 10개 장르에 대한 파이 차트를 생성

# %%
fig2 = px.pie(df_all[(df_all['platform']=='netflix')&(df_all['listed_in'].isin(top10_netflix))], names='listed_in',
             height=600, width=900,
             hole=0.7,
             title='넷플릭스 장르 상위 10위',
                   color_discrete_sequence=['#4c78a8', '#72b7b2'])
fig2.update_traces(hovertemplate=None, textposition='outside', textinfo='percent+label', rotation=0)
fig2.update_layout(margin=dict(t=100, b=30, l=0, r=0), showlegend=False,
                        plot_bgcolor='#fafafa', paper_bgcolor='#fafafa',
                        title_font=dict(size=20, color='#555', family="Lato, sans-serif"),
                        font=dict(size=9, color='#8a8d93'),
                        hoverlabel=dict(bgcolor="#444", font_size=13, font_family="Lato, sans-serif"))
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_group_genre[df_group_genre['platform']=='disney'].sort_values('show_id', ascending=False)[:10].style.background_gradient()
# Out:
# <style type="text/css">
# #T_5f418_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_5f418_row1_col2 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_5f418_row2_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_5f418_row3_col2, #T_5f418_row4_col2 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_5f418_row5_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_5f418_row6_col2 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_5f418_row7_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_5f418_row8_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_5f418_row9_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_5f418" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f418_level0_col0" class="col_heading level0 col0" >platform</th>
# ...

# %% [markdown]
# top10_disney는 디즈니플러스에서 가장 많은 컨텐츠를 가진 상위 10개의 장르를 나타내는 변수

# %%
top10_disney = df_group_genre[df_group_genre['platform']=='disney'].sort_values('show_id', ascending=False)[:10]['listed_in'].values.tolist()

# %%
fig2 = px.pie(df_all[(df_all['platform']=='disney')&(df_all['listed_in'].isin(top10_disney))], names='listed_in',
             height=600, width=900,
             hole=0.7,
             title='디즈니플러스 장르 상위 10위',
                   color_discrete_sequence=['#4c78a8', '#72b7b2'])
fig2.update_traces(hovertemplate=None, textposition='outside', textinfo='percent+label', rotation=0)
fig2.update_layout(margin=dict(t=100, b=30, l=0, r=0), showlegend=False,
                        plot_bgcolor='#fafafa', paper_bgcolor='#fafafa',
                        title_font=dict(size=20, color='#555', family="Lato, sans-serif"),
                        font=dict(size=9, color='#8a8d93'),
                        hoverlabel=dict(bgcolor="#444", font_size=13, font_family="Lato, sans-serif"))
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# We compared two platforms' genre (only top 10 genre respectively)
#
# We can find that Disney+ has advantages on Animation, comedy, Family genre while Netflix focuses on Drama, international movie and documentaries.

# %%
from wordcloud import WordCloud

# %%
# all data

plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(df_all['title']))
plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('graph.png')

plt.show()

# %%
# see Disney+ and netflix respectively.
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(16,8))
wordcloud1 = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(df_all[df_all['platform']=='disney']['title']))

ax1.imshow(wordcloud1)
wordcloud2 = WordCloud(
                          background_color='white',
                          width=512,
                          height=384
                         ).generate(" ".join(df_all[df_all['platform']=='netflix']['title']))

ax2.imshow(wordcloud2)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %% [markdown]
#  Notes:
# Based on word cloud graph, we can see the clear difference between two platform.
#
# This may related with Genre....

# %%
d1 = df_all[df_all["platform"] == "netflix"]
d2 = df_all[df_all["platform"] == "disney"]

col = "rating"

vc1 = d1[col].value_counts().reset_index()
vc1 = vc1.rename(columns={col: "count", "index": col})
vc1['percent'] = vc1['count'].apply(lambda x: 100 * x / sum(vc1['count']))
vc1 = vc1.sort_values(col)

vc2 = d2[col].value_counts().reset_index()
vc2 = vc2.rename(columns={col: "count", "index": col})
vc2['percent'] = vc2['count'].apply(lambda x: 100 * x / sum(vc2['count']))
vc2 = vc2.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], name="Netflix", marker=dict(color="#E50914"))
trace2 = go.Bar(x=vc2[col], y=vc2["count"], name="Disney+", marker=dict(color="#0047AB"))
data = [trace1, trace2]
layout = go.Layout(title="플랫폼별 연령등급", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data=data, layout=layout)
fig.update_layout(
    plot_bgcolor='#fafafa',
    paper_bgcolor='#fafafa'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Based on bar chart above, we can see the clear difference between two platform.
#
# Is Diseny+ a child-oriented ? Maybe...But the number of contents is quite different...so...We are not going to jump to the conclusion.
